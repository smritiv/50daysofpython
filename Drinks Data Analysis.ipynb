# %%
import pandas as pd
drinks = pd.read_csv('C:/Users/smrit/Downloads/drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
bycont=drinks.groupby(['continent']).sum(['beer_servings'])
print(bycont)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %%
bycont1=drinks.groupby(['continent']).mean()

bycont1
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
stats = drinks.groupby('continent').describe()
stats
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings              ... wine_servings         \
#              max           count        mean  ...           75%    max
# continent                                     ...
# AF         376.0            53.0   16.339623  ...         13.00  233.0
# AS         247.0            44.0   60.840909  ...          8.00  123.0
# EU         361.0            45.0  132.555556  ...        195.00  370.0
# ...

# %%
print(stats.wine_servings)
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
print(stats.beer_servings)
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
print(stats.spirit_servings)
# Out:
#            count        mean        std   min    25%    50%     75%    max
# continent
# AF          53.0   16.339623  28.102794   0.0   1.00    3.0   19.00  152.0
# AS          44.0   60.840909  84.362160   0.0   1.00   16.0   98.00  326.0
# EU          45.0  132.555556  77.589115   0.0  81.00  122.0  173.00  373.0
# OC          16.0   58.437500  70.504817   0.0  18.00   37.0   65.25  254.0
# SA          12.0  114.750000  77.077440  25.0  65.75  108.5  148.75  302.0

# %%
print(stats.total_litres_of_pure_alcohol)
# Out:
#            count      mean       std  min   25%    50%     75%   max
# continent
# AF          53.0  3.007547  2.647557  0.0  0.70   2.30   4.700   9.1
# AS          44.0  2.170455  2.770239  0.0  0.10   1.20   2.425  11.5
# EU          45.0  8.617778  3.358455  0.0  6.60  10.00  10.900  14.4
# OC          16.0  3.381250  3.345688  0.0  1.00   1.75   6.150  10.4
# SA          12.0  6.308333  1.531166  3.8  5.25   6.85   7.375   8.3

# %%
bycont.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count       5.000000         5.000000       5.000000
# mean     3428.800000      2364.000000    1796.000000
# std      3041.378914      2140.407905    2579.731866
# min      1435.000000       866.000000     399.000000
# 25%      1630.000000       935.000000     570.000000
# 50%      2101.000000      1377.000000     749.000000
# 75%      3258.000000      2677.000000     862.000000
# max      8720.000000      5965.000000    6400.000000
#
#        total_litres_of_pure_alcohol
# count                      5.000000
# mean                     154.500000
# std                      136.219951
# min                       54.100000
# 25%                       75.700000
# 50%                       95.500000
# 75%                      159.400000
# max                      387.800000

# %%
bycount=drinks.groupby(['continent']).count()

# %%
bycount
# Out:
#            country  beer_servings  spirit_servings  wine_servings  \
# continent
# AF              53             53               53             53
# AS              44             44               44             44
# EU              45             45               45             45
# OC              16             16               16             16
# SA              12             12               12             12
#
#            total_litres_of_pure_alcohol
# continent
# AF                                   53
# AS                                   44
# EU                                   45
# OC                                   16
# SA                                   12

# %%
fdrinks1 = drinks[(drinks.beer_servings>0)]
fdrinks2 = fdrinks1[(drinks.spirit_servings>0)]
fdrinks3 = fdrinks2[(drinks.wine_servings>0)]
fdrinks4 = fdrinks3[(drinks.total_litres_of_pure_alcohol>0)]
# Out:
# C:\Users\smrit\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\smrit\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\smrit\anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
fdrinks4
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania             89              132             54
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# ..                 ...            ...              ...            ...
# 187            Vanuatu             21               18             11
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# ...

# %%
fdrinks4.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     155.000000       155.000000     155.000000
# mean      128.045161        97.219355      58.638710
# std       100.715579        88.561320      83.873737
# min         1.000000         1.000000       1.000000
# 25%        36.000000        22.000000       4.000000
# 50%       105.000000        75.000000      13.000000
# 75%       204.500000       146.000000      82.500000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    155.000000
# mean                       5.515484
# std                        3.623788
# min                        0.100000
# 25%                        2.200000
# 50%                        5.400000
# 75%                        8.250000
# max                       14.400000

# %%
bycontinent=drinks.groupby(['continent', 'country']).sum(['total_litres_of_pure_alcohol'])
print(bycontinent)
# Out:
#                         beer_servings  spirit_servings  wine_servings  \
# continent country
# AF        Algeria                  25                0             14
#           Angola                  217               57             45
#           Benin                    34                4             13
#           Botswana                173               35             35
#           Burkina Faso             25                7              7
# ...                               ...              ...            ...
# SA        Paraguay                213              117             74
#           Peru                    163              160             21
#           Suriname                128              178              7
#           Uruguay                 115               35            220
#           Venezuela               333              100              3
#
#                         total_litres_of_pure_alcohol
# continent country
# ...

# %%
countryb = ''
countrys = ''
countryw = ''
countrypa= ''
beers = 0
spirits = 0
wine = 0
purealc = 0
for i in range(len(fdrinks4)):
    if fdrinks4.beer_servings[i] > beers:
        beers == beer_servings[i]
        countryb == fdrinks4.country[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-76fc8297ec02> in <module>
#       8 purealc = 0
# ...

# %%
bycontinent.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     170.000000       170.000000     170.000000
# mean      100.847059        69.529412      52.823529
# std       102.754951        81.058907      83.762227
# min         0.000000         0.000000       0.000000
# 25%        17.250000         3.000000       1.000000
# 50%        59.000000        36.500000       8.000000
# 75%       168.500000       114.000000      73.750000
# max       376.000000       373.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    170.000000
# mean                       4.544118
# std                        3.894511
# min                        0.000000
# 25%                        1.000000
# 50%                        3.950000
# 75%                        7.200000
# max                       14.400000

# %%
# %matplotlib inline
bycont1.plot(kind='bar')

# %%
minbeer = stats[('beer_servings','min')]
print(minbeer)
# Out:
# continent
# AF     0.0
# AS     0.0
# EU     0.0
# OC     0.0
# SA    93.0
# Name: (beer_servings, min), dtype: float64

# %%
for i in range(len(minbeer)):
    print(drinks[drinks.beer_servings == minbeer[i]])
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# ...

# %%
maxbeer = stats[('beer_servings','max')]
print(maxbeer)
# Out:
# continent
# AF    376.0
# AS    247.0
# EU    361.0
# OC    306.0
# SA    333.0
# Name: (beer_servings, max), dtype: float64

# %%
for i in range(len(maxbeer)):
    print(drinks[drinks.beer_servings == maxbeer[i]])
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
#                 country  beer_servings  spirit_servings  wine_servings  \
# 141  Russian Federation            247              326             73
#
#      total_litres_of_pure_alcohol continent
# 141                          11.5        AS
#            country  beer_servings  spirit_servings  wine_servings  \
# 45  Czech Republic            361              170            134
#
#     total_litres_of_pure_alcohol continent
# 45                          11.8        EU
#     country  beer_servings  spirit_servings  wine_servings  \
# 129   Palau            306               63             23
#
#      total_litres_of_pure_alcohol continent
# 129                           6.9        OC
#        country  beer_servings  spirit_servings  wine_servings  \
# ...

# %%
bycontinent1=drinks.groupby(['continent']).sum(['total_litres_of_pure_alcohol'])
print(bycontinent1)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %%
maxpurealc = stats[('total_litres_of_pure_alcohol','max')]
print(maxpurealc)
# Out:
# continent
# AF     9.1
# AS    11.5
# EU    14.4
# OC    10.4
# SA     8.3
# Name: (total_litres_of_pure_alcohol, max), dtype: float64

# %%
for i in range(len(maxpurealc)):
    print(drinks[drinks.total_litres_of_pure_alcohol == maxpurealc[i]])
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 124  Nigeria             42                5              2
#
#      total_litres_of_pure_alcohol continent
# 124                           9.1        AF
#                 country  beer_servings  spirit_servings  wine_servings  \
# 141  Russian Federation            247              326             73
#
#      total_litres_of_pure_alcohol continent
# 141                          11.5        AS
#     country  beer_servings  spirit_servings  wine_servings  \
# 15  Belarus            142              373             42
#
#     total_litres_of_pure_alcohol continent
# 15                          14.4        EU
#             country  beer_servings  spirit_servings  wine_servings  \
# 8         Australia            261               72            212
# 48          Denmark            224               81            278
# 140         Romania            297              122            167
# ...

# %%
conty = drinks[(drinks.continent='AF')]
