# %%
import pandas as pd
occup = pd.read_csv('C:/Users/smrit/Downloads/Occupation.csv')

# %%
occup.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
byoccup=occup.groupby(['occupation']).mean(['age'])
print(byoccup)
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %%
byoccup1=occup.groupby(['occupation']).count()
print(byoccup1)
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
byoccup1=occup.groupby(['occupation', 'gender']).count()
print(byoccup1)
# Out:
#                       user_id  age  zip_code
# occupation    gender
# administrator F            36   36        36
#               M            43   43        43
# artist        F            13   13        13
#               M            15   15        15
# doctor        M             7    7         7
# educator      F            26   26        26
#               M            69   69        69
# engineer      F             2    2         2
#               M            65   65        65
# entertainment F             2    2         2
#               M            16   16        16
# executive     F             3    3         3
#               M            29   29        29
# healthcare    F            11   11        11
#               M             5    5         5
# homemaker     F             6    6         6
#               M             1    1         1
# lawyer        F             2    2         2
#               M            10   10        10
# ...

# %%
byoccup2=occup.groupby(['occupation', 'gender']).max(['age'])
print(byoccup2)
# Out:
#                       user_id  age
# occupation    gender
# administrator F           922   62
#               M           940   70
# artist        F           920   48
#               M           865   45
# doctor        M           935   64
# educator      F           909   51
#               M           937   63
# engineer      F           827   36
#               M           934   70
# entertainment F           839   38
#               M           926   50
# executive     F           835   49
#               M           901   69
# healthcare    F           807   53
#               M           910   62
# homemaker     F           722   50
#               M           898   23
# lawyer        F           444   51
#               M           846   53
# librarian     F           942   59
#               M           906   69
# marketing     F           856   50
#               M           881   55
# none          F           756   55
#               M           628   33
# ...

# %%
byoccup2=occup.groupby(['occupation', 'gender']).min(['age'])
print(byoccup2)
# Out:
#                       user_id  age
# occupation    gender
# administrator F            34   22
#               M             7   21
# artist        F            23   19
#               M            31   20
# doctor        M           138   28
# educator      F            15   23
#               M            13   25
# engineer      F           786   23
#               M            25   22
# entertainment F           721   24
#               M            16   15
# executive     F            98   39
#               M             6   22
# healthcare    F           170   22
#               M            60   28
# homemaker     F            20   20
#               M           898   23
# lawyer        F           126   28
#               M            10   21
# librarian     F            27   26
#               M            19   23
# marketing     F            46   24
#               M            47   24
# none          F           256   26
#               M            57   11
# ...

# %%
byoccup2=occup.groupby(['occupation', 'gender']).mean(['age'])
print(byoccup2)
# Out:
#                          user_id        age
# occupation    gender
# administrator F       443.944444  40.638889
#               M       420.069767  37.162791
# artist        F       432.153846  30.307692
#               M       469.000000  32.333333
# doctor        M       533.714286  43.571429
# educator      F       454.730769  39.115385
#               M       471.492754  43.101449
# engineer      F       806.500000  29.500000
#               M       445.553846  36.600000
# entertainment F       780.000000  31.000000
#               M       350.250000  29.000000
# executive     F       373.000000  44.000000
#               M       427.413793  38.172414
# healthcare    F       568.454545  39.818182
#               M       354.000000  45.400000
# homemaker     F       367.166667  34.166667
#               M       898.000000  23.000000
# lawyer        F       285.000000  39.500000
#               M       373.900000  36.200000
# librarian     F       449.137931  40.000000
# ...

# %%
x = 'hello'
x = x.capitalize()
print(x)
# Out:
# Hello

# %%
for i in range(len(occup)):
    print(occup['occupation'][i])
    occup['occupation2'][i]=occup['occupation'][i].capitalize()
# Out:
# technician
# other
# writer
# technician
# other
# executive
# administrator
# administrator
# student
# lawyer
# other
# other
# educator
# scientist
# educator
# entertainment
# programmer
# other
# librarian
# homemaker
# writer
# writer
# artist
# artist
# engineer
# engineer
# librarian
# writer
# programmer
# student
# artist
# student
# student
# administrator
# homemaker
# student
# student
# other
# entertainment
# scientist
# engineer
# administrator
# librarian
# technician
# programmer
# marketing
# marketing
# administrator
# student
# writer
# educator
# student
# programmer
# executive
# programmer
# librarian
# none
# programmer
# educator
# healthcare
# engineer
# administrator
# marketing
# educator
# educator
# student
# student
# student
# engineer
# engineer
# scientist
# administrator
# student
# scientist
# entertainment
# student
# technician
# administrator
# administrator
# administrator
# student
# programmer
# other
# executive
# educator
# administrator
# ...

# %%
occup.head()
# Out:
#    user_id  age gender  occupation zip_code occupation2
# 0        1   24      M  technician    85711  Technician
# 1        2   53      F       other    94043       Other
# 2        3   23      M      writer    32067      Writer
# 3        4   24      M  technician    43537  Technician
# 4        5   33      F       other    15213       Other

# %%
def numericgen(x):
    if x=='M':
        return 1
    else:
        return 0
    
occup['numgender']=occup['gender'].apply(numericgen)

# %%
occup.head()
# Out:
#    user_id  age gender  occupation zip_code  numgender
# 0        1   24      M  technician    85711          1
# 1        2   53      F       other    94043          0
# 2        3   23      M      writer    32067          1
# 3        4   24      M  technician    43537          1
# 4        5   33      F       other    15213          0

# %%
maleratio=occup.groupby(['occupation']).numgender.sum()/occup.occupation.value_counts()

# %%
maleratio
# Out:
# administrator    0.544304
# artist           0.535714
# doctor           1.000000
# educator         0.726316
# engineer         0.970149
# entertainment    0.888889
# executive        0.906250
# healthcare       0.312500
# homemaker        0.142857
# lawyer           0.833333
# librarian        0.431373
# marketing        0.615385
# none             0.555556
# other            0.657143
# programmer       0.909091
# retired          0.928571
# salesman         0.750000
# scientist        0.903226
# student          0.693878
# technician       0.962963
# writer           0.577778
# dtype: float64

# %%
genocct=occup.groupby(['occupation','gender']).agg({'gender':'count'})

# %%
genocct.head()
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7

# %%
occt = occup.groupby(['occupation']).agg('count')

# %%
occt.head()
# Out:
#                user_id  age  gender  zip_code  numgender
# occupation
# administrator       79   79      79        79         79
# artist              28   28      28        28         28
# doctor               7    7       7         7          7
# educator            95   95      95        95         95
# engineer            67   67      67        67         67

# %%
genperc = genocct.div(occt,level='occupation')*100

# %%
genperc
# Out:
#                       age      gender  numgender  user_id  zip_code
# occupation    gender
# administrator F       NaN   45.569620        NaN      NaN       NaN
#               M       NaN   54.430380        NaN      NaN       NaN
# artist        F       NaN   46.428571        NaN      NaN       NaN
#               M       NaN   53.571429        NaN      NaN       NaN
# doctor        M       NaN  100.000000        NaN      NaN       NaN
# educator      F       NaN   27.368421        NaN      NaN       NaN
#               M       NaN   72.631579        NaN      NaN       NaN
# engineer      F       NaN    2.985075        NaN      NaN       NaN
#               M       NaN   97.014925        NaN      NaN       NaN
# entertainment F       NaN   11.111111        NaN      NaN       NaN
#               M       NaN   88.888889        NaN      NaN       NaN
# executive     F       NaN    9.375000        NaN      NaN       NaN
# ...

# %%
genperc1 = genocct.div(occt,level='gender')*100

# %%
genperc1
# Out:
#                       age  gender  numgender  user_id  zip_code
# occupation    gender
# administrator F       NaN     NaN        NaN      NaN       NaN
#               M       NaN     NaN        NaN      NaN       NaN
# artist        F       NaN     NaN        NaN      NaN       NaN
#               M       NaN     NaN        NaN      NaN       NaN
# doctor        M       NaN     NaN        NaN      NaN       NaN
# educator      F       NaN     NaN        NaN      NaN       NaN
#               M       NaN     NaN        NaN      NaN       NaN
# engineer      F       NaN     NaN        NaN      NaN       NaN
#               M       NaN     NaN        NaN      NaN       NaN
# entertainment F       NaN     NaN        NaN      NaN       NaN
#               M       NaN     NaN        NaN      NaN       NaN
# executive     F       NaN     NaN        NaN      NaN       NaN
#               M       NaN     NaN        NaN      NaN       NaN
# ...

# %%
occt1 = occup.groupby(['gender']).agg('count')

# %%
occt1.head()
# Out:
#         user_id  age  occupation  zip_code  numgender
# gender
# F           273  273         273       273        273
# M           670  670         670       670        670

# %%
genperc1 = genocct.div(occt1,level='gender')*100

# %%
genperc1
# Out:
#                       age  gender  numgender  occupation  user_id  zip_code
# occupation    gender
# administrator F       NaN     NaN        NaN         NaN      NaN       NaN
#               M       NaN     NaN        NaN         NaN      NaN       NaN
# artist        F       NaN     NaN        NaN         NaN      NaN       NaN
#               M       NaN     NaN        NaN         NaN      NaN       NaN
# doctor        M       NaN     NaN        NaN         NaN      NaN       NaN
# educator      F       NaN     NaN        NaN         NaN      NaN       NaN
#               M       NaN     NaN        NaN         NaN      NaN       NaN
# engineer      F       NaN     NaN        NaN         NaN      NaN       NaN
#               M       NaN     NaN        NaN         NaN      NaN       NaN
# entertainment F       NaN     NaN        NaN         NaN      NaN       NaN
#               M       NaN     NaN        NaN         NaN      NaN       NaN
# ...
